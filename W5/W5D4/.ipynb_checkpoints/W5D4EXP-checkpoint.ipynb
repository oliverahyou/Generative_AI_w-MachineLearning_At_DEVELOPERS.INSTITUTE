# %% [markdown]
# ## **Exercise 1: Identifying Data Types**
# Below are various data sources. Identify whether each one is an example of structured or unstructured data.
#
# Data source 1: A company’s financial reports stored in an Excel file.
# Type: Structured
#
# Data source 2: Photographs uploaded to a social media platform.
# Type: Unstructured
#
# Data source 3: A collection of news articles on a website.
# Type: Unstructured
#
# Data source 4: Inventory data in a relational database.
# Type: Structured
#
# Data source 5: Recorded interviews from a market research study.
# Type: Unstructured

# %% [markdown]
# ## **Exercise 2: Transformation Exercise**
# For each of the following unstructured data sources, propose a method to convert it into structured data. Explain your reasoning.
#
# Data source 1: A series of blog posts about travel experiences.
# Method: Extract information like location, date, and feeling at the time the post was written
# Reasoning: Allows for analysis and comparison of travel experiences
#
# Data source 2: Audio recordings of customer service calls.
# Method: Transcribe audio to text and extract relevant information like customer issues
# Reasoning: Allows for emotional analysis and identification of common problems faced by customers
#
# Data source 3: Handwritten notes from a brainstorming session.
# Method: Scan the notes and apply Optical Character Recognition (OCR) to convert them to digital text
# Reasoning: Allows for search and catergorisation of ideas
#
# Data source 4: A video tutorial on cooking.
# Method: Extract subtitles or transcribe the audio
# Reasoning: Allows for search and analysis of the content

# %% [markdown]
# ## **Exercise 3 : Import a file from Kaggle**
# Note: This dataset was originally sourced from Kaggle, but for easier access, it has been made available on GitHub.
#
# Please download the dataset directly from the GitHub repository to use it in this project.
# (https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/train.zip)
#
# Import the train dataset. Use the train.csv file.
# Print the first few rows of the DataFrame.

# %%
import pandas as pd
df = pd.read_csv('train.csv')
df.head()

# %% [markdown]
# ## **Exercise 4: Importing a CSV File**
# Use the Iris Dataset CSV.
# (https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/Iris_dataset.zip)
#
# + Download the Iris dataset CSV file and place it in the same directory as your Jupyter Notebook.
# + Import the CSV file using Pandas.
# + Display the first five rows of the dataset.

# %%
df = pd.read_csv("Iris_dataset.csv")
df.head(5)

# %% [markdown]
# ## **Exercise 5 : Export a dataframe to excel format and JSON format.**
#
# + Create a simple dataframe.
# + Export the dataframe to an excel file.
# + Export the dataframe to a JSON file.

# %%
data = {
    'Name': ['Sponge Bob', 'Sideshow Bob', 'Bob the Builder'],
    'Age': [20, 34, 42],
    'Country': ['USA', 'USA', 'UK']
}
df = pd.DataFrame(data)
df.to_excel("data.xlsx", index=False)
df.to_json('data.json', orient='records')

# %% [markdown]
# ## **Exercise 6: Reading JSON Data**
# Use a sample JSON dataset
# (https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/posts.zip)
#
# + Import the JSON data from the provided URL.
# + Use Pandas to read the JSON data.
# + Display the first five entries of the data.

# %%
json_data = pd.read_json('posts.json')
print(json_data.head(5))
