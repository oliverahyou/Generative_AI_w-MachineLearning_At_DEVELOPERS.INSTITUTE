# %% [markdown]
# ## **Daily Challenge: Hands-On Image Transformation and Visualization**
#
# **Task:**
#
# 1. Load and Visualize Images using the Flower Color Images dataset
# (https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D3%20-%20Importing%20Data,%20Exporting%20D/Flower%20Color%20Images%20Dataset.zip)
# 1. Download the dataset and unzip to use it
# 1. Install the libraries 'tensorflow', 'keras' and 'pillow'
# 1. To load an image and display it
# 1. Rotate an image by 30 degrees
# 1. Flip an image horizontally and then vertically using mirror and flip functions from ImageOps
# 1. Zoom in on an image (scale by 1.2x) using .resize(...)

# %%
import tensorflow as tf
from tensorflow import keras
from PIL import Image, ImageOps

# %%
img = Image.open('0001.png')
img.show()

# %%
rotated_img  = img.rotate(30)
rotated_img.show()

# %%
img_mirror = ImageOps.mirror(img)
img_mirror.show()

# %%
img_flip = ImageOps.flip(img)
img_flip.show()

# %%
width, height = img.size
zoom_factor = 1.2
new_width = int(width * zoom_factor)
new_height = int(height * zoom_factor)
zoomed_img = img.resize((new_width, new_height))
zoomed_img.show()
