# %% [markdown]
# ## **Exercise 1: Introduction to Data Analysis (Easy)**
#
# **Objectives:**
# Understand the basic overview and significance of data analysis.
# Write a short essay or report on the following topics:
# What is data analysis?
# Why is data analysis important in modern contexts?
# List and describe three areas where data analysis is applied today.
# Hint/Tip: Research current trends in data analysis and real-world examples to provide depth to your essay.

# %% [markdown]
# **Definition of Data Analysis:**
# Data analysis is the process of inspecting, cleansing, transforming, and modeling data with the goal of discovering useful information, drawing conclusions, and supporting decision-making.
# It involves various techniques and tools to analyze data sets, identify patterns, and extract insights that can better inform business strategies, scientific research, and policy-making.
#
# **Key Steps in Data Analysis:**
# + Data Collection: Gathering data from various sources such as databases, surveys, experiments or online platforms.
# + Data Cleaning: Removing or correcting errors and inconsistencies in the data to ensure its quality and reliability.
# + Data Exploration: Analyzing the data to understand its structure, identify patterns, anomalies or relationships for further analysis.
# + Data Interpretation: Drawing conclusions and insights from the analyzed data to inform decision-making or support hypotheses.
# + Data Visualization: Presenting the findings in a clear and understandable manner through charts, graphs, and reports.
# + Data Reporting: Communicating the results of the analysis to stakeholders in a clear and concise manner through presentations and reports
#
# **Importance of Data Analysis:**
# Properly executed data collection and its analysis could be the difference between success and failure for a business, organization, or any entity that relies on informed decision-making.
#
# **Applications of Data Analysis:**
# + Business strategy: Before the launch of a new product or service, successful companies often conduct market research and analyse consumer data  to further understand their target audience and their preferences. This allows them to finetune their products or services and marketing strategies to better meet the needs of their customers, ultimately leading to increased sales and customer satisfaction.
# + Scientific research: In scientific research, data analysis is crucial for interpreting experimental results and drawing meaningful conclusions. For example, in medical research, analyzing patient data can help identify patterns and correlations that may lead to new treatments or insights into diseases.
# + Government policy : Governments use data analysis to inform policy decision making, improve public services and public satisfaction.

# %% [markdown]
# ## **Exercise 2: Dataset Loading and Initial Analysis**
#
# **Objective:**
# Practice dataset loading from Kaggle and initial analysis.
#
# **Use the following datasets :**
# + How Much Sleep Do Americans Really Get?
# (https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D2%20-%20Data%20U.%20and%20pre-processing/How%20Much%20Sleep%20Do%20Americans.zip)
#
# + Global Trends in Mental Health Disorder
# (https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D2%20-%20Data%20U.%20and%20pre-processing/Global%20Trends%20in%20Mental%20Health%20Disorder.zip)
#
# + Credit Card Approvals
# (https://github.com/devtlv/Datasets-DA-Bootcamp-2-/raw/refs/heads/main/Week%204%20-%20Data%20Understanding/W4D2%20-%20Data%20U.%20and%20pre-processing/Credit%20Card%20Approvals%20(Clean%20Data).zip).
#
# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %%
import pandas as pd
df = pd.read_csv("Time Americans Spend Sleeping.csv")
df.head()

# %% [markdown]
# Brief description of the dataset:
# First 5 rows of a dataset contain information about the average hours per day Americans spend sleeping, along with the standard error, type of days, age group, activity, and sex.

# %%
df = pd.read_csv("Mental health Depression disorder Data.csv", low_memory=False)
df.head()

# %% [markdown]
# Brief description of the dataset:
# 5 rows of a dataset that contains information about the prevalence of various mental health disorders in Afghanistan from 1990 to 1994.

# %%
df = pd.read_csv("clean_dataset.csv")
df.head()

# %% [markdown]
# Brief description of the dataset:
# 5 rows of a dataset that contains bank details of customers, including their gender, age, debt, marital status, bank customer status, industry, ethnicity, years employed, prior default status, employment status, credit score, driver's license status, citizenship, zip code, income, and whether their loan application was approved.

# %% [markdown]
# ## **Exercise 3: Identifying Data Types**
#
# **Objective:** Learn to identify different data types.
# **Task:** For the datasets from the previous exercise, categorize each column of it as either quantitative or qualitative and explain your reasoning.

# %% [markdown]
# **Dataset 1: 'Time Americans Spend Sleeping.csv'**
#
# Column: Year
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Period
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: Avg hrs per day sleeping
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Standard Error
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Type of Days
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: Age Group
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: Activity
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: Sex
# Type: Qualitative
# Reason: Data that describes characteristics or opinions

# %% [markdown]
# **Dataset 2: 'Mental health Depression disorder Data.csv'**
#
# Column: Entity
# Type: Qualititative
# Reason:  Data that describes characteristics or opinions
#
# Column: Code
# Type: Qualititative
# Reason: Data that describes characteristics or opinions
#
# Column: Year
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Schizophrenia (%)
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Bipolar disorder (%)
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Eating disorders (%)
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Anxiety disorders (%)
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Drug use disorders (%)
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Depression (%)
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Alcohol use disorders (%)
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed

# %% [markdown]
# **Dataset 3: 'clean_dataset.csv'**
#
# Column: Gender
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: Age
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Debt
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Married
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: BankCustomer
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column:  Industry
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: Ethnicity
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: YearsEmployed
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: PriorDefault
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: Employed
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: CreditScore
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: DriversLicense
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: Citizen
# Type: Qualitative
# Reason: Data that describes characteristics or opinions
#
# Column: ZipCode
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Income
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Approved
# Type: Qualitative
# Reason: Data that describes characteristics or opinions

# %% [markdown]
# ## **Exercise 4: Exploring Data Types**

# %% [markdown]
# **Objective:** Learn about different types of data in data analysis.
# **Tasks:**
# + Load the Iris dataset using Kaggle into a Jupyter Notebook or Google Colaboratory Notebook.
# + Identify and list which columns in your dataset are qualitative and which are quantitative.
# + Write a brief description of why each column is classified as qualitative or quantitative.
#
# **Tools:** Jupyter Notebook, Python with Pandas library.

# %%
df = pd.read_csv("Iris.csv")
df.head()

# %% [markdown]
# Column: SepalLengthCm
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: SepalWidthCm
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: PetalLengthCm
# Type: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: PetalWidthCm
# PetalWidthCm: Quantitative
# Reason: Data that can be measured and statistically analyzed
#
# Column: Species
# Type: Qualitative
# Reason: Data that describes characteristics or opinions

# %% [markdown]
# ## **Exercise 5: Basic Data Analysis with Google Colab**
# **Objective:** Perform basic data analysis using Google Colab.
# **Task:**
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries
# Document your findings in the notebook.
#
# **Tools:** Google Colab, Python with Pandas and Matplotlib/Seaborn libraries.
#
# Quantitative column of reference used: **SepalLengthCm**

# %%
import matplotlib.pyplot as plt
mean_val = df["SepalLengthCm"].mean()
median_val = df["SepalLengthCm"].median()
mode_val = df["SepalLengthCm"].mode()[0]
plt.hist(df["SepalLengthCm"], bins=15, alpha=0.6)
plt.axvline(mean_val, color='red', label='Mean')
plt.axvline(median_val, color='green', label='Median')
plt.axvline(mode_val, color='blue', label='Mode')
plt.legend()
plt.show()

# %% [markdown]
# ## **Exercise 6: Basic Observation Skills in Data Analysis**
#
# **Objective:** Develop observation skills for data analysis.
# **Task:**
# + Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# + Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison) and explain your choice.
# + Tools: Jupyter Notebook, Python with Pandas library.

# %%
df = pd.read_csv("Time Americans Spend Sleeping.csv")
df.head()

# %% [markdown]
# **Colummns of interest:** Year, Avg hrs per day sleeping, Standard Error, Age Group
# **Types of analysis:**
# + **Group Comparison Analysis** could lead to insights on difference in sleeping patterns across different years, age groups, or types of days
# + **Correlation Analysis** could lead to insights on the potential increase or decrease of the average hours per day sleeping throughout the academic progression of the student population
# + **Cluster Analysis** could lead to insightful segmentation of student population intro clusters such as 'Well-rested', 'Sleep-deprived', and 'Average Sleepers'
